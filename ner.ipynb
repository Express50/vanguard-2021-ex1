# %%
import pandas as pd

import numpy as np
np.random.seed(1234)

# %%
train_all = pd.read_json('./FIGER/train.json', orient='records')

# %%
train_all.to_csv('./data/train_all.csv')

# %%
test_all = pd.read_json('./FIGER/test.json', orient='records')
test_all.to_csv('./data/test_all.csv')

# %%
dev_all = pd.read_json('./FIGER/dev.json', orient='records')
dev_all.to_csv('./data/dev_all.csv')

# %% [markdown]
# ### Subsampling and Cleaning

# %%
train_all = pd.read_csv('./data/train_all.csv', index_col=0)
# Out:
# C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# sub-sample 10,000 sentences
train_sample = train_all.sample(n=10000)
train_sample
# Out:
#                                                       sent  \
# 1220282  Teams come from all over the world to play : U...
# 274295   He was signed to the Chicago American Giants i...
# 544083   It is bounded on the northwest by the U.S. sta...
# 887317   The story is about an Old English Sheepdog who...
# 1633023  Ardiles-Waku Menga -LRB- born 28 September 198...
# ...                                                    ...
# 699527   Alison Hennegan is a lecturer at the Universit...
# 1388387  This album features Integrity worship leaders ...
# 35773    Ghulam Sarwar Nashir -LRB- 1922-1984 -RRB- , a...
# 487793   The Birmingham , Northfield by-election of 28 ...
# 367186   Semaphore is a north-western seaside suburb of...
#
#                                                     labels  start  end  \
# 1220282                                      ['/location']     79   85
# 274295   ['/news_agency', '/organization', '/organizati...    192  204
# 544083                 ['/location', '/location/province']    194  199
# 887317                                   ['/living_thing']     22   42
# 1633023     ['/organization/sports_team', '/organization']    124  142
# ...                                                    ...    ...  ...
# 699527   ['/organization', '/organization/educational_i...     37   60
# 1388387                      ['/person/artist', '/person']    109  121
# 35773                      ['/location/city', '/location']    153  159
# 487793   ['/government', '/organization', '/government/...     87   99
# 367186     ['/language', '/location/country', '/location']    154  163
#
#                                                       ents
# 1220282  [['Q30', 45, 58, 0.21681213], ['Q16', 61, 67, ...
# 274295   [['Q2963291', 21, 44, 0.64166665], ['Q2399847'...
# 544083   [['Q35657', 38, 48, 0.51353383], ['Q797', 52, ...
# 887317   [['Q37704', 22, 42, 0.5], ['Q6691229', 92, 95,...
# 1633023  [['Q92125', 13, 18, 0.17703058], ['Q1869064', ...
# ...                                                    ...
# 699527   [['Q4727092', 0, 15, 0.5], ['Q35794', 37, 60, ...
# 1388387  [['Q15401689', 20, 29, 0.2793484], ['Q842194',...
# 35773    [['Q5557675', 0, 13, 0.12280702], ['Q1869064',...
# 487793   [['Q3136714', 4, 27, 0.67899287], ['Q9626', 87...
# 367186   [['Q7449109', 0, 9, 0.2740553], ['Q6516641', 6...
#
# [10000 rows x 5 columns]

# %%
import ast

def clean(dataset, name='train'):
    # convert labels to list of strings
    dataset.labels = dataset.labels.apply(lambda x:  ast.literal_eval(x))
    dataset = dataset.explode('labels')
    dataset[['sent', 'labels', 'start', 'end']].to_csv(f'./data/{name}_clean.csv')

# %%
clean(train_sample, 'train')

# %%
dev_all = pd.read_csv('./data/dev_all.csv', index_col=0)
clean(dev_all, 'dev')

# %% [markdown]
# ### Creating BIO files that can be processed by spaCy
#
# example: https://github.com/explosion/spaCy/blob/master/extra/example_data/ner_example_data/ner-sent-per-line.iob

# %%
train_clean = pd.read_csv('./data/train_clean.csv', index_col=0)
dev_clean = pd.read_csv('./data/dev_clean.csv', index_col=0)
train_clean
# Out:
#                                                       sent  \
# 1220282  Teams come from all over the world to play : U...
# 274295   He was signed to the Chicago American Giants i...
# 274295   He was signed to the Chicago American Giants i...
# 274295   He was signed to the Chicago American Giants i...
# 544083   It is bounded on the northwest by the U.S. sta...
# ...                                                    ...
# 487793   The Birmingham , Northfield by-election of 28 ...
# 487793   The Birmingham , Northfield by-election of 28 ...
# 367186   Semaphore is a north-western seaside suburb of...
# 367186   Semaphore is a north-western seaside suburb of...
# 367186   Semaphore is a north-western seaside suburb of...
#
#                               labels  start  end
# 1220282                    /location     79   85
# 274295                  /news_agency    192  204
# 274295                 /organization    192  204
# 274295   /organization/sports_league    192  204
# 544083                     /location    194  199
# ...                              ...    ...  ...
# 487793                 /organization     87   99
# 487793   /government/political_party     87   99
# 367186                     /language    154  163
# 367186             /location/country    154  163
# 367186                     /location    154  163
#
# [24026 rows x 4 columns]

# %%
dev_clean
# Out:
#                                                    sent  \
# 0     He taught at the universities of Aberdeen , Li...
# 0     He taught at the universities of Aberdeen , Li...
# 0     He taught at the universities of Aberdeen , Li...
# 1     Carl Theodor 's mother was a sister of Queen E...
# 2     As a result of the Bolshevik Revolution in 191...
# ...                                                 ...
# 9998  In August , the Ayyubids conquered Ramla , Dar...
# 9999  Gemerska Ves is a village and municipality in ...
# 9999  Gemerska Ves is a village and municipality in ...
# 9999  Gemerska Ves is a village and municipality in ...
# 9999  Gemerska Ves is a village and municipality in ...
#
#                                      labels  start  end
# 0                             /organization     70   80
# 0     /organization/educational_institution     70   80
# 0                                 /location     70   80
# 1                                   /person     75  104
# 2                            /event/protest     19   39
# ...                                     ...    ...  ...
# 9998                              /location     35   40
# 9999                      /location/country     95  103
# 9999                            /government     95  103
# 9999                 /government/government     95  103
# 9999                              /location     95  103
#
# [23700 rows x 4 columns]

# %%
display(
    train_clean.sent.str.contains('[', regex=False).sum(),
    train_clean.sent.str.contains(']', regex=False).sum()
)
# Out:
# 0
# 0

# %%
# mark start and end of tag with [, ] characters (which are not used in text)
def mark_start_end(x):
    prefix = x['sent'][:x['start']]
    middle = x['sent'][x['start']:x['end']]
    postfix = x['sent'][x['end']:]
    
    return prefix + '[' + middle + ']' + postfix

# %%
# using [, ] marks, assign B/I/O tags to each token
def mark_BIO(x, tag):
    tokens = x.split(' ')
    # remove empty tokens
    tokens = [tok for tok in tokens if tok]
    marked_tokens = []
    started = False
    
    for tok in tokens:
        if tok.startswith('['):
            if tok.endswith(']'):
                marked_tokens.append(f'{tok[1:-1]}|B-{tag}')
            else:
                started = True
                marked_tokens.append(f'{tok[1:]}|B-{tag}')
        elif started:
            if tok.endswith(']'):
                started = False
                marked_tokens.append(f'{tok[:-1]}|I-{tag}')
            else:
                marked_tokens.append(f'{tok}|I-{tag}')
        else:
            marked_tokens.append(f'{tok}|O')
    
    return ' '.join(marked_tokens)

# %%
def bio_lambda(x):
    sent_marked = mark_start_end(x)
    sent_bio = mark_BIO(sent_marked, x['labels'])
    return sent_bio

# %%
train_clean['sent_BIO'] = train_clean.apply(bio_lambda, axis=1)

# %%
dev_clean['sent_BIO'] = dev_clean.apply(bio_lambda, axis=1)

# %%
np.savetxt('./data/train_clean.iob', train_clean.sent_BIO, fmt='%s')

# %%
np.savetxt('./data/dev_clean.iob', dev_clean.sent_BIO, fmt='%s')

# %% [markdown]
# ### NER with spaCy

# %%
# !python -m spacy convert ./data/train_clean.iob ./data -c iob
# Out:
# [i] Auto-detected sentence-per-line NER format
# [i] Grouping every 1 sentences into a document.
# [!] To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# [+] Generated output file (24027 documents): data\train_clean.spacy

# %%
# !python -m spacy convert ./data/dev_clean.iob ./data -c iob
# Out:
# [i] Auto-detected sentence-per-line NER format
# [i] Grouping every 1 sentences into a document.
# [!] To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# [+] Generated output file (23701 documents): data\dev_clean.spacy

# %%
# !python -m spacy debug config ./cfg/config.cfg
# Out:
# ============================= Config validation =============================
#
# ===================== Config validation for [initialize] =====================
#
# ====================== Config validation for [training] ======================
# [+] Config is valid

# %%
# !python -m spacy debug data ./cfg/config.cfg
# Out:
# ============================ Data file validation ============================
# [+] Corpus is loadable
# [+] Pipeline can be initialized with data
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 24026 training docs
# 23700 evaluation docs
# [!] 62 training examples also in evaluation data
#
# ============================== Vocab & Vectors ==============================
# [i] 698332 total word(s) in the data (42276 unique)
# [i] No word vectors present in the package
#
# ========================== Named Entity Recognition ==========================
# [i] 0 new label(s), 112 existing label(s)
# 0 missing value(s) (tokens with '-' label)
# [!] 280 entity span(s) with punctuation
# [+] Good amount of examples for all labels
# [+] Examples without occurrences available for all labels
# [+] No entities consisting of or starting/ending with whitespace
# Entity spans consisting of or starting/ending with punctuation can not be
# trained with a noise level > 0.
#
# ================================== Summary ==================================
# [+] 5 checks passed
# [!] 2 warnings

# %%
# !python train.py

# %% [markdown]
# ### Exploration

# %%
train_clean = pd.read_csv('./data/train_clean.csv', index_col=0)
train_clean.head()

# %%
# extract spans using start, end
train_100000['span'] = train_100000.apply(lambda x: x['sent'][x['start'] : x['end']], axis=1)
