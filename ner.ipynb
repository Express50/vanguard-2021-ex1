# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer

import numpy as np
np.random.seed(1234)

# %%
train_all = pd.read_json('./FIGER/train.json', orient='records')

# %%
train_all.to_csv('./data/train_all.csv')

# %%
test_all = pd.read_json('./FIGER/test.json', orient='records')
test_all.to_csv('./data/test_all.csv')

# %%
dev_all = pd.read_json('./FIGER/dev.json', orient='records')
dev_all.to_csv('./data/dev_all.csv')

# %% [markdown]
# ### Subsampling and Cleaning

# %%
train_all = pd.read_csv('./data/train_all.csv', index_col=0)

# %%
# sub-sample 100,000 sentences
train_100000 = train_all.sample(n=100000)
train_100000

# %%
train_100000.to_csv('./data/train_100000.csv')

# %%
train_100000 = pd.read_csv('./data/train_100000.csv', index_col=0)
train_100000
# Out:
#                                                       sent  \
# 972798   In 1961 a George Jones version of the song was...
# 1816704  He had already inked Gene Colan there on a lon...
# 1291792  Other early pioneers were the Usher family , w...
# 1265539  Blood Into Wine is a documentary about the Nor...
# 798      In 317 BC , Cassander , after defeating Olympi...
# ...                                                    ...
# 464708   Such films include Seven Notes In Black -LRB- ...
# 1299913  Released by White Noise Records in 1979 after ...
# 1157145  She studied painting first with a teacher from...
# 970084   He earned a Ph. D in history from the Universi...
# 1735279  In 1788 Van der Noot travelled to England , th...
#
#                                                     labels  start  end  \
# 972798                                          ['/music']     83  126
# 1816704                                  ['/written_work']     91  108
# 1291792                                          ['/food']     79   83
# 1265539     ['/person/actor', '/person/artist', '/person']     86  106
# 798                                            ['/person']     40   48
# ...                                                    ...    ...  ...
# 464708                               ['/art', '/art/film']     88   98
# 1299913  ['/person/musician', '/person/actor', '/person...    101  112
# 1157145                    ['/location/city', '/location']     68   73
# 970084                                   ['/written_work']    125  158
# 1735279                 ['/location/country', '/location']     48   62
#
#                                                       ents
# 972798   [['Q508202', 10, 22, 0.666855], ['Q165745', 63...
# 1816704  [['Q1266750', 21, 31, 0.6346333], ['Q180704', ...
# 1291792                  [['Q165911', 30, 35, 0.27522305]]
# 1265539  [['Q4927812', 0, 15, 0.7084944], ['Q582744', 5...
# 798      [['Q207183', 12, 21, 0.770825], ['Q223134', 40...
# ...                                                    ...
# 464708   [['Q190908', 19, 24, 0.15525861], ['Q1869064',...
# 1299913  [['Q7995120', 12, 31, 0.5784357], ['Q347986', ...
# 1157145  [['Q128499', 68, 73, 0.32345238], ['Q656', 86,...
# 970084   [['Q752297', 12, 17, 0.1392031], ['Q230492', 3...
# 1735279  [['Q689056', 16, 20, 0.28553542], ['Q179876', ...
#
# [100000 rows x 5 columns]

# %%
# convert labels to list of strings
import ast
train_100000.labels = train_100000.labels.apply(lambda x:  ast.literal_eval(x))

# %%
# extract spans using start, end
train_100000['span'] = train_100000.apply(lambda x: x['sent'][x['start'] : x['end']], axis=1)

# %%
train_100000
# Out:
#                                                       sent  \
# 972798   In 1961 a George Jones version of the song was...
# 1816704  He had already inked Gene Colan there on a lon...
# 1291792  Other early pioneers were the Usher family , w...
# 1265539  Blood Into Wine is a documentary about the Nor...
# 798      In 317 BC , Cassander , after defeating Olympi...
# ...                                                    ...
# 464708   Such films include Seven Notes In Black -LRB- ...
# 1299913  Released by White Noise Records in 1979 after ...
# 1157145  She studied painting first with a teacher from...
# 970084   He earned a Ph. D in history from the Universi...
# 1735279  In 1788 Van der Noot travelled to England , th...
#
#                                                     labels  start  end  \
# 972798                                            [/music]     83  126
# 1816704                                    [/written_work]     91  108
# 1291792                                            [/food]     79   83
# 1265539           [/person/actor, /person/artist, /person]     86  106
# 798                                              [/person]     40   48
# ...                                                    ...    ...  ...
# 464708                                   [/art, /art/film]     88   98
# 1299913  [/person/musician, /person/actor, /person/arti...    101  112
# 1157145                        [/location/city, /location]     68   73
# 970084                                     [/written_work]    125  158
# 1735279                     [/location/country, /location]     48   62
#
#                                                       ents  \
# 972798   [['Q508202', 10, 22, 0.666855], ['Q165745', 63...
# 1816704  [['Q1266750', 21, 31, 0.6346333], ['Q180704', ...
# 1291792                  [['Q165911', 30, 35, 0.27522305]]
# 1265539  [['Q4927812', 0, 15, 0.7084944], ['Q582744', 5...
# 798      [['Q207183', 12, 21, 0.770825], ['Q223134', 40...
# ...                                                    ...
# 464708   [['Q190908', 19, 24, 0.15525861], ['Q1869064',...
# 1299913  [['Q7995120', 12, 31, 0.5784357], ['Q347986', ...
# 1157145  [['Q128499', 68, 73, 0.32345238], ['Q656', 86,...
# 970084   [['Q752297', 12, 17, 0.1392031], ['Q230492', 3...
# 1735279  [['Q689056', 16, 20, 0.28553542], ['Q179876', ...
#
#                                                 span
# 972798   George Jones Sings Country and Western Hits
# 1816704                            Tales of Suspense
# 1291792                                         wine
# 1265539                         Maynard James Keenan
# 798                                         Olympias
# ...                                              ...
# 464708                                    The Beyond
# 1299913                                  Steve Jones
# 1157145                                        Yalta
# 970084             Science and Civilisation in China
# 1735279                               Dutch Republic
#
# [100000 rows x 6 columns]

# %%
train_100000 = train_100000.explode('labels')

# %%
train_100000[['sent', 'labels', 'start', 'end', 'span']].to_csv('./data/train_clean.csv')

# %% [markdown]
# ### Creating BIO files that can be processed by spaCy
#
# example: https://github.com/explosion/spaCy/blob/master/extra/example_data/ner_example_data/ner-sent-per-line.iob

# %%
train_clean = pd.read_csv('./data/train_clean.csv', index_col=0)
train_clean
# Out:
#                                                       sent             labels  \
# 972798   In 1961 a George Jones version of the song was...             /music
# 1816704  He had already inked Gene Colan there on a lon...      /written_work
# 1291792  Other early pioneers were the Usher family , w...              /food
# 1265539  Blood Into Wine is a documentary about the Nor...      /person/actor
# 1265539  Blood Into Wine is a documentary about the Nor...     /person/artist
# ...                                                    ...                ...
# 1157145  She studied painting first with a teacher from...     /location/city
# 1157145  She studied painting first with a teacher from...          /location
# 970084   He earned a Ph. D in history from the Universi...      /written_work
# 1735279  In 1788 Van der Noot travelled to England , th...  /location/country
# 1735279  In 1788 Van der Noot travelled to England , th...          /location
#
#          start  end                                         span
# 972798      83  126  George Jones Sings Country and Western Hits
# 1816704     91  108                            Tales of Suspense
# 1291792     79   83                                         wine
# 1265539     86  106                         Maynard James Keenan
# 1265539     86  106                         Maynard James Keenan
# ...        ...  ...                                          ...
# 1157145     68   73                                        Yalta
# 1157145     68   73                                        Yalta
# 970084     125  158            Science and Civilisation in China
# 1735279     48   62                               Dutch Republic
# 1735279     48   62                               Dutch Republic
#
# [239047 rows x 5 columns]

# %%
display(
    train_clean.sent.str.contains('[', regex=False).sum(),
    train_clean.sent.str.contains(']', regex=False).sum()
)
# Out:
# 0
# 0

# %%
# mark start and end of tag with [, ] characters (which are not used in text)
def mark_start_end(x):
    prefix = x['sent'][:x['start']]
    middle = x['sent'][x['start']:x['end']]
    postfix = x['sent'][x['end']:]
    
    return prefix + '[' + middle + ']' + postfix

# %%
# using [, ] marks, assign B/I/O tags to each token
def mark_BIO(x, tag):
    tokens = x.split(' ')
    marked_tokens = []
    started = False
    
    for tok in tokens:
        if tok.startswith('['):
            if tok.endswith(']'):
                marked_tokens.append(f'{tok[1:-1]}|B-{tag}')
            else:
                started = True
                marked_tokens.append(f'{tok[1:]}|B-{tag}')
        elif started:
            if tok.endswith(']'):
                started = False
                marked_tokens.append(f'{tok[:-1]}|I-{tag}')
            else:
                marked_tokens.append(f'{tok}|I-{tag}')
        else:
            marked_tokens.append(f'{tok}|O')
    
    return ' '.join(marked_tokens)

# %%
def bio_lambda(x):
    sent_marked = mark_start_end(x)
    sent_bio = mark_BIO(sent_marked, x['labels'])
    return sent_bio

train_clean['sent_BIO'] = train_clean.apply(bio_lambda, axis=1)

# %%
train_clean
# Out:
#                                                       sent             labels  \
# 972798   In 1961 a George Jones version of the song was...             /music
# 1816704  He had already inked Gene Colan there on a lon...      /written_work
# 1291792  Other early pioneers were the Usher family , w...              /food
# 1265539  Blood Into Wine is a documentary about the Nor...      /person/actor
# 1265539  Blood Into Wine is a documentary about the Nor...     /person/artist
# ...                                                    ...                ...
# 1157145  She studied painting first with a teacher from...     /location/city
# 1157145  She studied painting first with a teacher from...          /location
# 970084   He earned a Ph. D in history from the Universi...      /written_work
# 1735279  In 1788 Van der Noot travelled to England , th...  /location/country
# 1735279  In 1788 Van der Noot travelled to England , th...          /location
#
#          start  end                                         span  \
# 972798      83  126  George Jones Sings Country and Western Hits
# 1816704     91  108                            Tales of Suspense
# 1291792     79   83                                         wine
# 1265539     86  106                         Maynard James Keenan
# 1265539     86  106                         Maynard James Keenan
# ...        ...  ...                                          ...
# 1157145     68   73                                        Yalta
# 1157145     68   73                                        Yalta
# 970084     125  158            Science and Civilisation in China
# 1735279     48   62                               Dutch Republic
# 1735279     48   62                               Dutch Republic
#
#                                                   sent_BIO
# 972798   In|O 1961|O a|O George|O Jones|O version|O of|...
# 1816704  He|O had|O already|O inked|O Gene|O Colan|O th...
# 1291792  Other|O early|O pioneers|O were|O the|O Usher|...
# 1265539  Blood|O Into|O Wine|O is|O a|O documentary|O a...
# 1265539  Blood|O Into|O Wine|O is|O a|O documentary|O a...
# ...                                                    ...
# 1157145  She|O studied|O painting|O first|O with|O a|O ...
# 1157145  She|O studied|O painting|O first|O with|O a|O ...
# 970084   He|O earned|O a|O Ph.|O D|O in|O history|O fro...
# 1735279  In|O 1788|O Van|O der|O Noot|O travelled|O to|...
# 1735279  In|O 1788|O Van|O der|O Noot|O travelled|O to|...
#
# [239047 rows x 6 columns]

# %%
np.savetxt('./data/train_clean_BIO.txt', train_clean.sent_BIO.sample(100), fmt='%s')

# %% [markdown]
# ### Exploration

# %%
train_clean = pd.read_csv('./data/train_clean.csv', index_col=0)
train_clean.head()
# Out:
#                                                       sent  \
# 972798   In 1961 a George Jones version of the song was...
# 1816704  He had already inked Gene Colan there on a lon...
# 1291792  Other early pioneers were the Usher family , w...
# 1265539  Blood Into Wine is a documentary about the Nor...
# 798      In 317 BC , Cassander , after defeating Olympi...
#
#                                                  labels  start  end  \
# 972798                                       ['/music']     83  126
# 1816704                               ['/written_work']     91  108
# 1291792                                       ['/food']     79   83
# 1265539  ['/person/actor', '/person/artist', '/person']     86  106
# 798                                         ['/person']     40   48
#
#                                                 span
# 972798   George Jones Sings Country and Western Hits
# 1816704                            Tales of Suspense
# 1291792                                         wine
# 1265539                         Maynard James Keenan
# 798                                         Olympias

# %% [markdown]
# ### NER with spaCy

# %%
# !python -m spacy convert ./data/train_clean_BIO.txt ./data -c iob
# Out:
# [i] Auto-detected sentence-per-line NER format
# [i] Grouping every 1 sentences into a document.
# [!] To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# [+] Generated output file (101 documents):
# data\train_clean_BIO.spacy

# %%
# !python -m spacy debug config ./cfg/config.cfg
# Out:
# ============================= Config validation =============================
#
# ===================== Config validation for [initialize] =====================
#
# ====================== Config validation for [training] ======================
# [+] Config is valid

# %%
# !python -m spacy debug data ./cfg/config.cfg
# Out:
# ============================ Data file validation ============================
# [+] Corpus is loadable
# [+] Pipeline can be initialized with data
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 100 training docs
# 100 evaluation docs
# [!] 100 training examples also in evaluation data
# [!] Low number of examples to train a new pipeline (100)
#
# ============================== Vocab & Vectors ==============================
# [i] 2881 total word(s) in the data (1388 unique)
# [i] No word vectors present in the package
#
# ========================== Named Entity Recognition ==========================
# [i] 0 new label(s), 33 existing label(s)
# 0 missing value(s) (tokens with '-' label)
# [+] Good amount of examples for all labels
# [+] Examples without occurrences available for all labels
# [+] No entities consisting of or starting/ending with whitespace
# [+] No entities consisting of or starting/ending with punctuation
#
# ================================== Summary ==================================
# [+] 6 checks passed
# [!] 2 warnings

# %%
# !python train.py
# Out:
# ^C
# [+] Created output directory: training
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     41.44    0.00    0.00    0.00    0.00
#   6     200        315.32   2004.79   34.04   36.36   32.00    0.34
#  14     400        394.00    849.83   95.48   95.96   95.00    0.95
#  25     600         52.61    131.38  100.00  100.00  100.00    1.00
#  37     800         17.55     14.03  100.00  100.00  100.00    1.00
#  53    1000          2.11      1.03  100.00  100.00  100.00    1.00
#  72    1200          8.95      2.72  100.00  100.00  100.00    1.00
#  96    1400         92.95     37.00  100.00  100.00  100.00    1.00
# 125    1600         72.07     21.48  100.00  100.00  100.00    1.00
# 160    1800         84.40     13.66  100.00  100.00  100.00    1.00
# 203    2000         37.77      6.94  100.00  100.00  100.00    1.00
# 253    2200        113.34     22.05  100.00  100.00  100.00    1.00
# 319    2400        650.08     54.55  100.00  100.00  100.00    1.00
# 386    2600        230.14     30.16  100.00  100.00  100.00    1.00
# 453    2800         35.25      7.04  100.00  100.00  100.00    1.00
# 519    3000        116.39     21.60  100.00  100.00  100.00    1.00
# 586    3200         14.07      2.54  100.00  100.00  100.00    1.00
# 653    3400         59.78      7.29  100.00  100.00  100.00    1.00
# 719    3600         43.95      7.85  100.00  100.00  100.00    1.00
# 786    3800        142.92     21.70  100.00  100.00  100.00    1.00
# 853    4000        178.70     15.28  100.00  100.00  100.00    1.00
# 919    4200        150.66     18.48  100.00  100.00  100.00    1.00
# 986    4400        186.37     19.96  100.00  100.00  100.00    1.00
# 1053    4600        105.17     13.98  100.00  100.00  100.00    1.00
# 1119    4800        157.71     17.17  100.00  100.00  100.00    1.00
# 1186    5000        115.16     13.06  100.00  100.00  100.00    1.00
# [!] Aborting and saving the final best model. Encountered exception:
# FileNotFoundError(2, 'The system cannot find the path specified')
# Set up nlp object from config
# Pipeline: ['tok2vec', 'ner']
# Created vocabulary
# Finished initializing nlp object
# Initialized pipeline components: ['tok2vec', 'ner']
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\spacy\__main__.py", line 4, in <module>
#     setup_cli()
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\spacy\cli\_util.py", line 68, in setup_cli
#     command(prog_name=COMMAND)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\click\core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\click\core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\click\core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\click\core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\click\core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\typer\main.py", line 497, in wrapper
#     return callback(**use_params)  # type: ignore
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\spacy\cli\train.py", line 59, in train_cli
#     train(nlp, output_path, use_gpu=use_gpu, stdout=sys.stdout, stderr=sys.stderr)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\spacy\training\loop.py", line 114, in train
#     raise e
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\spacy\training\loop.py", line 104, in train
#     save_checkpoint(is_best_checkpoint)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\site-packages\spacy\training\loop.py", line 72, in save_checkpoint
#     shutil.rmtree(output_path / DIR_MODEL_BEST)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\shutil.py", line 740, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\shutil.py", line 599, in _rmtree_unsafe
#     onerror(os.scandir, path, sys.exc_info())
#   File "C:\ProgramData\Anaconda3\envs\vanguard_2\lib\shutil.py", line 596, in _rmtree_unsafe
#     with os.scandir(path) as scandir_it:
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'training\\model-best'
